# %% [markdown]
# # Group By
#
# Any groupby operation involves one of the following operations on the original object. They are −
#
# Splitting the Object
#
# Applying a function
#
# Combining the results
#
# In many situations, we split the data into sets and we apply some functionality on each subset. In the apply functionality, we can perform the following operations −
#
# Aggregation − computing a summary statistic
#
# Transformation − perform some group-specific operation
#
# Filtration − discarding the data with some condition

# %%
import pandas as pd

# %%
imdb_df = pd.read_csv("data/imdb_1000.csv")

# %%
imdb_df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
genre_groups = imdb_df.groupby('Genre')

# %%
genre_groups

# %%
genre_groups.get_group('Horror,Thriller')
# Out:
#      Rank                     Title            Genre  \
# 2       3                     Split  Horror,Thriller
# 27     28                Dead Awake  Horror,Thriller
# 116   117            The Neon Demon  Horror,Thriller
# 361   362                     Clown  Horror,Thriller
# 382   383                      Hush  Horror,Thriller
# 477   478                       Pet  Horror,Thriller
# 531   532            Friend Request  Horror,Thriller
# 723   724               Blair Witch  Horror,Thriller
# 736   737  The Blackcoat's Daughter  Horror,Thriller
# 748   749     Ouija: Origin of Evil  Horror,Thriller
# 776   777                        31  Horror,Thriller
# 811   812                      Mama  Horror,Thriller
# 819   820        Wolves at the Door  Horror,Thriller
# 825   826                Crawlspace  Horror,Thriller
# 970   971         Texas Chainsaw 3D  Horror,Thriller
# 986   987       Final Destination 5  Horror,Thriller
#
# ...

# %%
genre_groups.aggregate('mean').sort_values('Rating')
# Out:
#                                    Rank         Year  Runtime (Minutes)  \
# Genre
# Fantasy,Horror,Thriller      648.000000  2016.000000         133.000000
# Comedy,Western               643.000000  2015.000000         119.000000
# Sci-Fi                       400.500000  2016.000000         106.500000
# Sci-Fi,Thriller              513.000000  2008.000000          91.000000
# Action,Fantasy,Thriller      586.000000  2007.000000         114.000000
# Drama,Horror,Thriller        384.666667  2015.000000          92.833333
# Action,Horror                318.000000  2016.000000          81.000000
# Action,Crime,Sport           494.000000  2015.000000         114.000000
# Comedy,Family,Fantasy       1000.000000  2016.000000          87.000000
# Adventure,Horror             350.500000  2014.500000          92.000000
# Horror,Sci-Fi,Thriller       396.333333  2015.000000          93.000000
# Horror                       578.090909  2011.090909          94.545455
# ...

# %%
import numpy as np

# %%
genre_groups['Runtime (Minutes)'].aggregate([np.max, np.min, np.mean, np.std])
# Out:
#                             amax  amin        mean        std
# Genre
# Action                        90    86   88.000000   2.828427
# Action,Adventure             139    98  124.333333  22.854613
# Action,Adventure,Biography   141   122  131.500000  13.435029
# Action,Adventure,Comedy      129    83  109.642857  12.469083
# Action,Adventure,Crime       129    98  116.500000  12.533954
# Action,Adventure,Drama       159    97  124.166667  15.964114
# Action,Adventure,Family      130    92  105.500000  16.941074
# Action,Adventure,Fantasy     169    85  118.148148  20.635488
# Action,Adventure,Horror      116    97  106.500000  13.435029
# Action,Adventure,Mystery     146   118  128.600000  11.738824
# Action,Adventure,Romance     125   110  117.500000  10.606602
# Action,Adventure,Sci-Fi      165    88  127.360000  16.680381
# Action,Adventure,Thriller    148   103  126.363636  16.181920
# Action,Adventure,Western     150   132  141.000000  12.727922
# ...

# %%
imdb_df['avg_duration'] = genre_groups['Runtime (Minutes)'].transform(lambda x: x.mean())

# %%
imdb_df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
imdb_df['Genre'].value_counts()
# Out:
# Action,Adventure,Sci-Fi       50
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Animation,Adventure,Comedy    27
# Action,Adventure,Fantasy      27
# Comedy,Drama                  27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Crime,Drama,Mystery           23
# Action,Adventure,Drama        18
# Action,Crime,Drama            17
# Horror,Thriller               16
# Drama,Thriller                15
# Adventure,Family,Fantasy      14
# Action,Adventure,Comedy       14
# Biography,Drama               14
# Biography,Drama,History       14
# Action,Comedy,Crime           12
# Action,Crime,Thriller         12
# Action,Adventure,Thriller     11
# Horror                        11
# Crime,Drama                   10
# Animation,Action,Adventure     9
# Horror,Mystery,Thriller        9
# Biography,Crime,Drama          9
# Thriller                       9
# ...

# %%
genre_groups.filter(lambda x: x['Runtime (Minutes)'].mean() < 120)['Genre'].value_counts()
# Out:
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Animation,Adventure,Comedy    27
# Comedy,Drama                  27
# Action,Adventure,Fantasy      27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Crime,Drama,Mystery           23
# Action,Crime,Drama            17
# Horror,Thriller               16
# Drama,Thriller                15
# Action,Adventure,Comedy       14
# Biography,Drama               14
# Action,Crime,Thriller         12
# Action,Comedy,Crime           12
# Horror                        11
# Crime,Drama                   10
# Thriller                       9
# Action,Thriller                9
# Horror,Mystery,Thriller        9
# Animation,Action,Adventure     9
# Adventure,Comedy,Drama         8
# Action,Sci-Fi,Thriller         7
# Comedy,Crime,Drama             7
# Biography,Comedy,Drama         7
# Action,Drama,Thriller          7
# ...
